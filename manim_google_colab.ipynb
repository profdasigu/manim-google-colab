# %% [markdown]
# <a href="https://colab.research.google.com/github/profdasigu/manim-google-colab/blob/main/manim_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output
# Importa a função 'clear_output' para limpar a  saída da célula no Jupyter/Colab.

# !sudo apt update
# Executa a atualização da lista de pacotes do sistema Ubuntu, garantindo que todos os pacotes disponíveis estejam atualizados.

# !sudo apt install libcairo2-dev libpango1.0-dev ffmpeg
# Instala bibliotecas essenciais para o funcionamento do Manim e LaTeX, como 'libcairo2-dev' (para gráficos), 'libpango1.0-dev' (para renderização de texto) e 'ffmpeg' (para manipulação de áudio e vídeo).

# !sudo apt install texlive texlive-latex-extra
# Instala o pacote básico do LaTeX ('texlive') e pacotes adicionais ('texlive-latex-extra') necessários para compilar documentos LaTeX complexos.

# # LaTeX additional packages
# !sudo apt install texlive-science texlive-fonts-extra
# Instala pacotes adicionais do LaTeX - Colocar aqui todos os pacotes do LaTeX que irá utilizar.
# O 'texlive-science' é usado para incluir pacotes científicos, e 'texlive-fonts-extra' instala fontes extras utilizadas em documentos LaTeX.

# !pip install manim
# Instala o Manim, uma biblioteca Python para criação de animações matemáticas.

clear_output()
# Limpa a saída da célula no ambiente Colab, removendo mensagens e logs dos comandos anteriores.

# !manim --version
# Verifica e exibe a versão do Manim instalada no ambiente.

exit()
# Reinicia o ambiente de execução (runtime) para garantir que as alterações sejam aplicadas corretamente.

# %%
from manim import *
# Importa todos os módulos e funções do Manim, que é uma biblioteca Python para criar animações matemáticas.

config.verbosity = "WARNING"
# Define o nível de verbosidade (detalhes nas mensagens de log) como "WARNING", ou seja, apenas mensagens de aviso e erros importantes serão mostradas, ocultando informações menos relevantes.

# %%
from google.colab import drive
# Importa a biblioteca 'drive' para trabalhar com o Google Drive no ambiente do Google Colab.

drive.mount('/content/drive')
# Monta o Google Drive no diretório '/content/drive' do Google Colab, permitindo acessar e salvar arquivos diretamente no Drive.

# %%
# Cole aqui o código gerado pela IA

# %%
# %%manim -qm NOME_DO_CLASS_CODIGO_GERADO_COM_O_CODIGO
